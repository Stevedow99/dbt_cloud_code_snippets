# %% [markdown]
# # dbtc - Getting Job Information From dbt Cloud Jobs
#
# ___
#
# ### In this notebook we do the following:
# - Import the dbtc package (dbt Cloud API SDK)
# - Kick off a dbt Cloud job run
# - Retrieve the status of that job run
# - Grab artifacts from the job run
#
#
# dbtc docs can be found [here](https://dbtc.dpguthrie.com/0.3/guide/cloud/)

# %% [markdown]
# ___
# #### Installing dbtc

# %%
from dbtc import dbtCloudClient
import time

# %% [markdown]
# ___
# #### Defing the service token

# %%
# dbt_cloud_service_token = '||DBT CLOUD API TOKEN GOES HERE||'

# %% [markdown]
# ___
# #### Enabling the client
#
# - If on dbt Cloud Standard than the host will be `cloud.getdbt.com`
# - If on dbt Cloud VPC then host will be `<<your_dbt_cloud_instance_base_name>>.getdbt.com`

# %%
# setting up the connection

dbt_cloud_client = dbtCloudClient(service_token=dbt_cloud_service_token, host="cloud.getdbt.com")

# %% [markdown]
# ___
# #### Setting up the inputs
#
#
# Example Payload - API docs are [here](https://documenter.getpostman.com/view/14183654/UVsSNiXC#148fd718-6440-46f2-998a-8a05eb5df4ad)
#
# ```{
#   "cause": "Kicked off from Airflow",
#   "git_branch": "staging",
#   "schema_override": "dbt_cloud_pr_123",
#   "dbt_version_override": "1.0.1",
#   "target_name_override": "staging",
#   "timeout_seconds_override": 3000,
#   "generate_docs_override": true,
#   "threads_override": 8,
#   "steps_override": [
#     "dbt seed",
#     "dbt run --fail-fast",
#     "dbt test --fail-fast"
#   ]
# }'```

# %%
dbt_cloud_account_id = 77338
dbt_cloud_job_id = 106702
job_payload = {
  "cause": "Kicked off from Jupyter Notebook by Steve",
   "steps_override": [
      "dbt seed",
      "dbt build --select +exposure:company_sales_dashboard"
    ]
}

# %% [markdown]
# ___
# #### Kicking off the job

# %%
# triggering dbt cloud job 
job_trigger = dbt_cloud_client.cloud.trigger_job(account_id = dbt_cloud_account_id, 
                                      job_id = dbt_cloud_job_id, 
                                      payload = job_payload, 
                                      should_poll = True,
                                      poll_interval = 30)

print(job_trigger)
# Out:
# [22:41:50] Status: "Queued", Elapsed time: 0s, View here:                                             ]8;id=871003;file:///opt/homebrew/lib/python3.9/site-packages/dbtc/client/admin.py\admin.py]8;;\:]8;id=60098;file:///opt/homebrew/lib/python3.9/site-packages/dbtc/client/admin.py#1367\1367]8;;\
#            https://cloud.getdbt.com/deploy/77338/projects/131392/runs/133312814/
# [22:42:20] Status: "Running", Elapsed time: 30.0s, View here:                                         ]8;id=389322;file:///opt/homebrew/lib/python3.9/site-packages/dbtc/client/admin.py\admin.py]8;;\:]8;id=212497;file:///opt/homebrew/lib/python3.9/site-packages/dbtc/client/admin.py#1375\1375]8;;\
#            https://cloud.getdbt.com/deploy/77338/projects/131392/runs/133312814/
# [22:42:50] Status: "Success", Elapsed time: 61.0s, View here:                                         ]8;id=188712;file:///opt/homebrew/lib/python3.9/site-packages/dbtc/client/admin.py\admin.py]8;;\:]8;id=995917;file:///opt/homebrew/lib/python3.9/site-packages/dbtc/client/admin.py#1375\1375]8;;\
#            https://cloud.getdbt.com/deploy/77338/projects/131392/runs/133312814/
# {'status': {'code': 200, 'is_success': True, 'user_message': 'Success!', 'developer_message': ''}, 'data': {'id': 133312814, 'trigger_id': 134027946, 'account_id': 77338, 'environment_id': 105436, 'project_id': 131392, 'job_definition_id': 106702, 'status': 10, 'dbt_version': '1.3.0-latest', 'git_branch': 'main', 'git_sha': '1026a0cfbcecf9b4515f87b669d1e14c71a24eeb', 'status_message': None, 'owner_thread_id': None, 'executed_by_thread_id': 'dbt-run-133312814', 'deferring_run_id': None, 'artifacts_saved': True, 'artifact_s3_path': 'prod/runs/133312814/artifacts/target', 'has_docs_generated': False, 'has_sources_generated': False, 'notifications_sent': True, 'blocked_by': [], 'scribe_enabled': True, 'created_at': '2023-03-23 02:41:49.932767+00:00', 'updated_at': '2023-03-23 02:42:41.128068+00:00', 'dequeued_at': '2023-03-23 02:41:49.992520+00:00', 'started_at': '2023-03-23 02:41:56.194958+00:00', 'finished_at': '2023-03-23 02:42:41.014429+00:00', 'last_checked_at': '2023-03-23 02:42:41.049938+00:00', 'last_heartbeat_at': '2023-03-23 02:42:26.179027+00:00', 'should_start_at': '2023-03-23 02:41:49.932767+00:00', 'trigger': None, 'job': None, 'environment': None, 'run_steps': [], 'status_humanized': 'Success', 'in_progress': False, 'is_complete': True, 'is_success': True, 'is_error': False, 'is_cancelled': False, 'href': 'https://cloud.getdbt.com/deploy/77338/projects/131392/runs/133312814/', 'duration': '00:00:51', 'queued_duration': '00:00:06', 'run_duration': '00:00:44', 'duration_humanized': '51 seconds', 'queued_duration_humanized': '6 seconds', 'run_duration_humanized': '44 seconds', 'created_at_humanized': '1 minute ago', 'finished_at_humanized': '9 seconds ago', 'job_id': 106702, 'is_running': None}}

# %% [markdown]
# ___
# #### Retrieving info from a run

# %%
# pulling the job run id from the object that kicked off the job above
job_run_id = job_trigger['data']['id']

# defining run status
run_info = dbt_cloud_client.cloud.get_run(account_id = dbt_cloud_account_id, 
                               run_id = job_run_id)

# printing the run info
print(run_info)

# example run info below
# Out:
# {'status': {'code': 200, 'is_success': True, 'user_message': 'Success!', 'developer_message': ''}, 'data': {'id': 133312814, 'trigger_id': 134027946, 'account_id': 77338, 'environment_id': 105436, 'project_id': 131392, 'job_definition_id': 106702, 'status': 10, 'dbt_version': '1.3.0-latest', 'git_branch': 'main', 'git_sha': '1026a0cfbcecf9b4515f87b669d1e14c71a24eeb', 'status_message': None, 'owner_thread_id': None, 'executed_by_thread_id': 'dbt-run-133312814', 'deferring_run_id': None, 'artifacts_saved': True, 'artifact_s3_path': 'prod/runs/133312814/artifacts/target', 'has_docs_generated': False, 'has_sources_generated': False, 'notifications_sent': True, 'blocked_by': [], 'scribe_enabled': True, 'created_at': '2023-03-23 02:41:49.932767+00:00', 'updated_at': '2023-03-23 02:42:41.128068+00:00', 'dequeued_at': '2023-03-23 02:41:49.992520+00:00', 'started_at': '2023-03-23 02:41:56.194958+00:00', 'finished_at': '2023-03-23 02:42:41.014429+00:00', 'last_checked_at': '2023-03-23 02:42:41.049938+00:00', 'last_heartbeat_at': '2023-03-23 02:42:26.179027+00:00', 'should_start_at': '2023-03-23 02:41:49.932767+00:00', 'trigger': None, 'job': None, 'environment': None, 'run_steps': [], 'status_humanized': 'Success', 'in_progress': False, 'is_complete': True, 'is_success': True, 'is_error': False, 'is_cancelled': False, 'href': 'https://cloud.getdbt.com/deploy/77338/projects/131392/runs/133312814/', 'duration': '00:00:51', 'queued_duration': '00:00:06', 'run_duration': '00:00:44', 'duration_humanized': '51 seconds', 'queued_duration_humanized': '6 seconds', 'run_duration_humanized': '44 seconds', 'created_at_humanized': '1 minute, 38 seconds ago', 'finished_at_humanized': '47 seconds ago', 'job_id': 106702, 'is_running': None}}

# %% [markdown]
# ___
# ### Example run info returned as dict:
#
# </br>
#
# ```{'status': {'code': 200, 'is_success': True, 'user_message': 'Success!', 'developer_message': ''}, 'data': {'id': 100846129, 'trigger_id': 101561260, 'account_id': 123456, 'environment_id': 56789, 'project_id': 569888, 'job_definition_id': 569845, 'status': 10, 'dbt_version': '1.2.0-latest', 'git_branch': 'main', 'git_sha': '6231f4a8bc92452454fea8d20bb0d84dd4b32407', 'status_message': None, 'owner_thread_id': None, 'executed_by_thread_id': 'dbt-run-569888', 'deferring_run_id': None, 'artifacts_saved': True, 'artifact_s3_path': 'prod/runs/569888/artifacts/target', 'has_docs_generated': False, 'has_sources_generated': False, 'notifications_sent': True, 'blocked_by': [], 'scribe_enabled': True, 'created_at': '2022-11-28 21:30:52.210228+00:00', 'updated_at': '2022-11-28 21:31:11.610886+00:00', 'dequeued_at': '2022-11-28 21:30:52.248203+00:00', 'started_at': '2022-11-28 21:30:57.237571+00:00', 'finished_at': '2022-11-28 21:31:11.208356+00:00', 'last_checked_at': '2022-11-28 21:31:11.514719+00:00', 'last_heartbeat_at': '2022-11-28 21:30:57.223247+00:00', 'should_start_at': '2022-11-28 21:30:52.210228+00:00', 'trigger': None, 'job': None, 'environment': None, 'run_steps': [], 'status_humanized': 'Success', 'in_progress': False, 'is_complete': True, 'is_success': True, 'is_error': False, 'is_cancelled': False, 'href': 'https://cloud.getdbt.com/next/deploy/123456/projects/161955/runs/569845/', 'duration': '00:00:18', 'queued_duration': '00:00:05', 'run_duration': '00:00:13', 'duration_humanized': '18 seconds', 'queued_duration_humanized': '5 seconds', 'run_duration_humanized': '13 seconds', 'created_at_humanized': '5 minutes, 17 seconds ago', 'finished_at_humanized': '4 minutes, 58 seconds ago', 'job_id': 569845, 'is_running': None}}```

# %% [markdown]
# ___
# #### Grabbing run artifacts
# - The most common run artifacts are `(manifest.json, catalog.json, run_results.json, and sources.json)`
# - For more info on what artifacts you can get from a run, click [here](https://docs.getdbt.com/reference/artifacts/dbt-artifacts)

# %%
# listing the cloud run artifacts
cloud_run_artifacts = dbt_cloud_client.cloud.list_run_artifacts(account_id = dbt_cloud_account_id, 
                               run_id = job_run_id)


# print them out
cloud_run_artifacts
# Out:
# {'status': {'code': 200,
#   'is_success': True,
#   'user_message': 'Success!',
#   'developer_message': ''},
#  'data': ['compiled/sample_demo/models/marts/aggregates/aggregates.yml/not_null_monthly_gross_revenue_order_month.sql',
#   'compiled/sample_demo/models/marts/aggregates/monthly_gross_revenue.sql',
#   'compiled/sample_demo/models/marts/core/core.yml/accepted_values_dim_customers_19c499e4c12e802c2c2bd2047d4767fc.sql',
#   'compiled/sample_demo/models/marts/core/core.yml/not_null_dim_customers_customer_key.sql',
#   'compiled/sample_demo/models/marts/core/core.yml/not_null_fct_order_items_nation_key.sql',
#   'compiled/sample_demo/models/marts/core/core.yml/not_null_fct_order_items_order_item_key.sql',
#   'compiled/sample_demo/models/marts/core/core.yml/relationships_fct_orders_01863b95ad98bb6a66c90da6f065c2ae.sql',
#   'compiled/sample_demo/models/marts/core/core.yml/unique_dim_customers_customer_key.sql',
#   'compiled/sample_demo/models/marts/core/core.yml/unique_fct_order_items_order_item_key.sql',
#   'compiled/sample_demo/models/marts/core/dim_customers.sql',
#   'compiled/sample_demo/models/marts/core/fct_order_items.sql',
#   'compiled/sample_demo/models/marts/intermediate/intermediate.yml/not_null_order_items_order_item_key.sql',
#   'compiled/sample_demo/models/marts/intermediate/intermediate.yml/not_null_part_suppliers_part_supplier_key.sql',
#   'compiled/sample_demo/models/marts/intermediate/intermediate.yml/unique_order_items_order_item_key.sql',
#   'compiled/sample_demo/models/marts/intermediate/intermediate.yml/unique_part_suppliers_part_supplier_key.sql',
#   'compiled/sample_demo/models/marts/intermediate/order_items.sql',
#   'compiled/sample_demo/models/marts/intermediate/part_suppliers.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_customers_customer_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_line_items_order_item_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_nations_nation_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_orders_order_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_part_suppliers_part_supplier_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_parts_part_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_regions_region_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_suppliers_supplier_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_customers_customer_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_line_items_order_item_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_nations_nation_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_orders_order_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_part_suppliers_part_supplier_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_parts_part_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_regions_region_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_suppliers_supplier_key.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch_customers.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch_line_items.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch_nations.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch_orders.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch_part_suppliers.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch_parts.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch_regions.sql',
#   'compiled/sample_demo/models/staging/tpch/stg_tpch_suppliers.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_customer_c_custkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_nation_n_nationkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_orders_o_orderkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_part_p_partkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_region_r_regionkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_supplier_s_suppkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_line_0403124f3724b4d6984e362cbdf30740.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_line_43b59984a4c7b172d1e95c13fec6bd9c.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_line_56b786676a582f41b4502498079b8292.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_nati_863138f31f617783ad556b879ab65039.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_orde_aa2aa3d71f8f1d2febff342069b4fe2b.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_part_a4c1d3c0d0f0db1ff9c10bf48b8c8fe8.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_part_c5396ae9effd9c1528d06af4f91b3817.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_supp_1c9d96c407a8f937b03dcfc97848e71b.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_customer_c_custkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_nation_n_nationkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_orders_o_orderkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_part_p_partkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_region_r_regionkey.sql',
#   'compiled/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_supplier_s_suppkey.sql',
#   'compiled/sample_demo/tests/stg_tpch_orders_assert_positive_price.sql',
#   'manifest.json',
#   'run/sample_demo/models/marts/aggregates/aggregates.yml/not_null_monthly_gross_revenue_order_month.sql',
#   'run/sample_demo/models/marts/aggregates/monthly_gross_revenue.sql',
#   'run/sample_demo/models/marts/core/core.yml/accepted_values_dim_customers_19c499e4c12e802c2c2bd2047d4767fc.sql',
#   'run/sample_demo/models/marts/core/core.yml/not_null_dim_customers_customer_key.sql',
#   'run/sample_demo/models/marts/core/core.yml/not_null_fct_order_items_nation_key.sql',
#   'run/sample_demo/models/marts/core/core.yml/not_null_fct_order_items_order_item_key.sql',
#   'run/sample_demo/models/marts/core/core.yml/relationships_fct_orders_01863b95ad98bb6a66c90da6f065c2ae.sql',
#   'run/sample_demo/models/marts/core/core.yml/unique_dim_customers_customer_key.sql',
#   'run/sample_demo/models/marts/core/core.yml/unique_fct_order_items_order_item_key.sql',
#   'run/sample_demo/models/marts/core/dim_customers.sql',
#   'run/sample_demo/models/marts/core/fct_order_items.sql',
#   'run/sample_demo/models/marts/intermediate/intermediate.yml/not_null_order_items_order_item_key.sql',
#   'run/sample_demo/models/marts/intermediate/intermediate.yml/not_null_part_suppliers_part_supplier_key.sql',
#   'run/sample_demo/models/marts/intermediate/intermediate.yml/unique_order_items_order_item_key.sql',
#   'run/sample_demo/models/marts/intermediate/intermediate.yml/unique_part_suppliers_part_supplier_key.sql',
#   'run/sample_demo/models/marts/intermediate/order_items.sql',
#   'run/sample_demo/models/marts/intermediate/part_suppliers.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_customers_customer_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_line_items_order_item_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_nations_nation_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_orders_order_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_part_suppliers_part_supplier_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_parts_part_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_regions_region_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_suppliers_supplier_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_customers_customer_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_line_items_order_item_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_nations_nation_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_orders_order_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_part_suppliers_part_supplier_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_parts_part_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_regions_region_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch.yml/unique_stg_tpch_suppliers_supplier_key.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch_customers.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch_line_items.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch_nations.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch_orders.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch_part_suppliers.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch_parts.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch_regions.sql',
#   'run/sample_demo/models/staging/tpch/stg_tpch_suppliers.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_customer_c_custkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_nation_n_nationkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_orders_o_orderkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_part_p_partkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_region_r_regionkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_not_null_tpch_supplier_s_suppkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_line_0403124f3724b4d6984e362cbdf30740.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_line_43b59984a4c7b172d1e95c13fec6bd9c.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_line_56b786676a582f41b4502498079b8292.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_nati_863138f31f617783ad556b879ab65039.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_orde_aa2aa3d71f8f1d2febff342069b4fe2b.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_part_a4c1d3c0d0f0db1ff9c10bf48b8c8fe8.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_part_c5396ae9effd9c1528d06af4f91b3817.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_relationships_tpch_supp_1c9d96c407a8f937b03dcfc97848e71b.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_customer_c_custkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_nation_n_nationkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_orders_o_orderkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_part_p_partkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_region_r_regionkey.sql',
#   'run/sample_demo/models/staging/tpch/tpch_sources.yml/source_unique_tpch_supplier_s_suppkey.sql',
#   'run/sample_demo/seeds/warehouse_contract_rates.csv',
#   'run/sample_demo/tests/stg_tpch_orders_assert_positive_price.sql',
#   'run_results.json']}

# %% [markdown]
# ___
# #### Looking at a run artifact -- example with a model

# %%
# getting the model run artifact
model_artifact = dbt_cloud_client.cloud.get_run_artifact(account_id = dbt_cloud_account_id, 
                                              run_id = job_run_id,
                                              path = "run/sample_demo/models/staging/tpch/stg_tpch.yml/not_null_stg_tpch_parts_part_key.sql")


# printing out the model artifact 
print(model_artifact)
# Out:
# select
#       count(*) as failures,
#       count(*) != 0 as should_warn,
#       count(*) != 0 as should_error
#     from (
#
#
#
#
#
#
# select part_key
# from STEVE_D_PRODUCTION.Curated_staging.stg_tpch_parts
# where part_key is null
#
#
#
#
#     ) dbt_internal_test

# %% [markdown]
# ___
# #### Looking at a run artifact -- example with run results
#
# - For more info on what you can get from the run results artifact, click [here](https://docs.getdbt.com/reference/artifacts/run-results-json)

# %%
# getting the run results artifact
rr_artifact = dbt_cloud_client.cloud.get_run_artifact(account_id = dbt_cloud_account_id, 
                                              run_id = job_run_id,
                                              path = "run_results.json")


# printing out the run results artifact
rr_artifact
# Out:
# {'metadata': {'dbt_schema_version': 'https://schemas.getdbt.com/dbt/run-results/v4.json',
#   'dbt_version': '1.3.3',
#   'generated_at': '2023-03-23T02:42:35.845197Z',
#   'invocation_id': '6095fe48-a54a-48b6-a10c-e7abc0d19464',
#   'env': {'DBT_CLOUD_PROJECT_ID': '131392',
#    'DBT_CLOUD_RUN_ID': '133312814',
#    'DBT_CLOUD_JOB_ID': '106702',
#    'DBT_CLOUD_RUN_REASON': 'Kicked off from Jupyter Notebook by Steve',
#    'DBT_CLOUD_RUN_REASON_CATEGORY': 'other'}},
#  'results': [{'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:19.489193Z',
#      'completed_at': '2023-03-23T02:42:19.556709Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:19.586858Z',
#      'completed_at': '2023-03-23T02:42:20.081864Z'}],
#    'thread_id': 'Thread-29',
#    'execution_time': 0.7755222320556641,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.source_not_null_tpch_customer_c_custkey.a95b6298b5'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:19.494766Z',
#      'completed_at': '2023-03-23T02:42:19.557278Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:19.604322Z',
#      'completed_at': '2023-03-23T02:42:20.099065Z'}],
#    'thread_id': 'Thread-30',
#    'execution_time': 0.7937076091766357,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.source_not_null_tpch_nation_n_nationkey.5ac5d27298'},
#   {'status': 'success',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:19.488857Z',
#      'completed_at': '2023-03-23T02:42:19.573134Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:19.607128Z',
#      'completed_at': '2023-03-23T02:42:20.223916Z'}],
#    'thread_id': 'Thread-28',
#    'execution_time': 0.9159295558929443,
#    'adapter_response': {'_message': 'SUCCESS 1',
#     'code': 'SUCCESS',
#     'rows_affected': 1,
#     'query_id': '01ab2102-0602-b8fd-0004-7d83095abb1a'},
#    'message': 'SUCCESS 1',
#    'failures': None,
#    'unique_id': 'model.sample_demo.stg_tpch_part_suppliers'},
#   {'status': 'success',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:19.488304Z',
#      'completed_at': '2023-03-23T02:42:19.556368Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:19.557913Z',
#      'completed_at': '2023-03-23T02:42:20.225706Z'}],
#    'thread_id': 'Thread-27',
#    'execution_time': 0.9333875179290771,
#    'adapter_response': {'_message': 'SUCCESS 1',
#     'code': 'SUCCESS',
#     'rows_affected': 1,
#     'query_id': '01ab2102-0602-b8fd-0004-7d83095abb16'},
#    'message': 'SUCCESS 1',
#    'failures': None,
#    'unique_id': 'model.sample_demo.stg_tpch_line_items'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:20.263987Z',
#      'completed_at': '2023-03-23T02:42:20.270326Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:20.270743Z',
#      'completed_at': '2023-03-23T02:42:20.745495Z'}],
#    'thread_id': 'Thread-29',
#    'execution_time': 0.6512784957885742,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.source_not_null_tpch_orders_o_orderkey.ebd571817b'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:20.282631Z',
#      'completed_at': '2023-03-23T02:42:20.287589Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:20.288037Z',
#      'completed_at': '2023-03-23T02:42:20.763731Z'}],
#    'thread_id': 'Thread-30',
#    'execution_time': 0
},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:28.318095Z',
#      'completed_at': '2023-03-23T02:42:28.329549Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:28.330476Z',
#      'completed_at': '2023-03-23T02:42:28.909352Z'}],
#    'thread_id': 'Thread-27',
#    'execution_time': 0.7654578685760498,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.not_null_order_items_order_item_key.44b9fa7311'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:28.318312Z',
#      'completed_at': '2023-03-23T02:42:28.329780Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:28.333080Z',
#      'completed_at': '2023-03-23T02:42:28.991772Z'}],
#    'thread_id': 'Thread-30',
#    'execution_time': 0.8430302143096924,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.unique_order_items_order_item_key.43a40b2837'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:28.977742Z',
#      'completed_at': '2023-03-23T02:42:28.983974Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:28.984477Z',
#      'completed_at': '2023-03-23T02:42:29.507989Z'}],
#    'thread_id': 'Thread-28',
#    'execution_time': 0.7026572227478027,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.not_null_dim_customers_customer_key.4bebfb3411'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:28.943386Z',
#      'completed_at': '2023-03-23T02:42:28.957417Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:28.957812Z',
#      'completed_at': '2023-03-23T02:42:29.515828Z'}],
#    'thread_id': 'Thread-29',
#    'execution_time': 0.7487432956695557,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.accepted_values_dim_customers_region__AFRICA__MIDDLE_EAST__ASIA__EUROPE__AMERICA.dad4601b69'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:29.084037Z',
#      'completed_at': '2023-03-23T02:42:29.089223Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:29.089607Z',
#      'completed_at': '2023-03-23T02:42:29.556354Z'}],
#    'thread_id': 'Thread-27',
#    'execution_time': 0.6500985622406006,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.unique_dim_customers_customer_key.ad8156656e'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:29.162679Z',
#      'completed_at': '2023-03-23T02:42:29.180420Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:29.181088Z',
#      'completed_at': '2023-03-23T02:42:29.756938Z'}],
#    'thread_id': 'Thread-30',
#    'execution_time': 0.795579195022583,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.not_null_part_suppliers_part_supplier_key.b8b2022ed3'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:29.698154Z',
#      'completed_at': '2023-03-23T02:42:29.705033Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:29.705440Z',
#      'completed_at': '2023-03-23T02:42:30.304928Z'}],
#    'thread_id': 'Thread-29',
#    'execution_time': 0.7968568801879883,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.relationships_fct_orders_customer_key__customer_key__ref_dim_customers_.018eb0a60b'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:29.681710Z',
#      'completed_at': '2023-03-23T02:42:29.687844Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:29.688342Z',
#      'completed_at': '2023-03-23T02:42:30.369128Z'}],
#    'thread_id': 'Thread-28',
#    'execution_time': 0.8831706047058105,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.unique_part_suppliers_part_supplier_key.909477afa8'},
#   {'status': 'success',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:30.566847Z',
#      'completed_at': '2023-03-23T02:42:30.572705Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:30.573088Z',
#      'completed_at': '2023-03-23T02:42:32.476499Z'}],
#    'thread_id': 'Thread-27',
#    'execution_time': 2.083913803100586,
#    'adapter_response': {'_message': 'SUCCESS 1',
#     'code': 'SUCCESS',
#     'rows_affected': 1,
#     'query_id': '01ab2102-0602-b880-0004-7d83095aad8a'},
#    'message': 'SUCCESS 1',
#    'failures': None,
#    'unique_id': 'model.sample_demo.fct_order_items'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:32.656587Z',
#      'completed_at': '2023-03-23T02:42:32.671997Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:32.673294Z',
#      'completed_at': '2023-03-23T02:42:33.452013Z'}],
#    'thread_id': 'Thread-29',
#    'execution_time': 0.9800755977630615,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.not_null_fct_order_items_nation_key.c3faf47d8e'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:32.656811Z',
#      'completed_at': '2023-03-23T02:42:32.672334Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:32.676227Z',
#      'completed_at': '2023-03-23T02:42:33.453825Z'}],
#    'thread_id': 'Thread-28',
#    'execution_time': 0.9880821704864502,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.not_null_fct_order_items_order_item_key.47516a6371'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:32.657027Z',
#      'completed_at': '2023-03-23T02:42:32.672707Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:32.678895Z',
#      'completed_at': '2023-03-23T02:42:33.494144Z'}],
#    'thread_id': 'Thread-30',
#    'execution_time': 1.0100085735321045,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.unique_fct_order_items_order_item_key.4d6426a255'},
#   {'status': 'success',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:33.667677Z',
#      'completed_at': '2023-03-23T02:42:33.672139Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:33.672527Z',
#      'completed_at': '2023-03-23T02:42:34.937036Z'}],
#    'thread_id': 'Thread-27',
#    'execution_time': 1.4481887817382812,
#    'adapter_response': {'_message': 'SUCCESS 1',
#     'code': 'SUCCESS',
#     'rows_affected': 1,
#     'query_id': '01ab2102-0602-b880-0004-7d83095aad8e'},
#    'message': 'SUCCESS 1',
#    'failures': None,
#    'unique_id': 'model.sample_demo.monthly_gross_revenue'},
#   {'status': 'pass',
#    'timing': [{'name': 'compile',
#      'started_at': '2023-03-23T02:42:35.118264Z',
#      'completed_at': '2023-03-23T02:42:35.124824Z'},
#     {'name': 'execute',
#      'started_at': '2023-03-23T02:42:35.125229Z',
#      'completed_at': '2023-03-23T02:42:35.663428Z'}],
#    'thread_id': 'Thread-28',
#    'execution_time': 0.7234032154083252,
#    'adapter_response': {},
#    'message': None,
#    'failures': 0,
#    'unique_id': 'test.sample_demo.not_null_monthly_gross_revenue_order_month.91ce1f4bd2'}],
#  'elapsed_time': 18.626567363739014,
#  'args': {'write_json': True,
#   'use_colors': True,
#   'printer_width': 80,
#   'version_check': True,
#   'partial_parse': True,
#   'static_parser': True,
#   'profiles_dir': '/tmp/jobs/133312814/.dbt',
#   'send_anonymous_usage_stats': True,
#   'event_buffer_size': 100000,
#   'quiet': False,
#   'no_print': False,
#   'cache_selected_only': False,
#   'profile': 'user',
#   'target': 'default',
#   'indirect_selection': 'eager',
#   'resource_types': [],
#   'select': ['+exposure:company_sales_dashboard'],
#   'which': 'build',
#   'rpc_method': 'build'}}

# %% [markdown]
# ___
# #### Run Results helps you get detailed metadata from the run
#
# **For example, you can look at things like:**
#
# - Model Run Metadata:
#
# ``` json
#     {
#       "status": "success",
#       "timing": [
#         {
#           "name": "compile",
#           "started_at": "2023-03-23T02:42:28.220249Z",
#           "completed_at": "2023-03-23T02:42:28.225185Z"
#         },
#         {
#           "name": "execute",
#           "started_at": "2023-03-23T02:42:28.225581Z",
#           "completed_at": "2023-03-23T02:42:28.801870Z"
#         }
#       ],
#       "thread_id": "Thread-28",
#       "execution_time": 0.7557363510131836,
#       "adapter_response": {
#         "_message": "SUCCESS 1",
#         "code": "SUCCESS",
#         "rows_affected": 1,
#         "query_id": "01ab2102-0602-b8fd-0004-7d83095abb7a"
#       },
#       "message": "SUCCESS 1",
#       "failures": None,
#       "unique_id": "model.sample_demo.part_suppliers"
#     }
# ```

# %% [markdown]
# - _Test Runs_:
#
# ``` json
#     {
#       "status": "pass",
#       "timing": [
#         {
#           "name": "compile",
#           "started_at": "2023-03-23T02:42:28.318312Z",
#           "completed_at": "2023-03-23T02:42:28.329780Z"
#         },
#         {
#           "name": "execute",
#           "started_at": "2023-03-23T02:42:28.333080Z",
#           "completed_at": "2023-03-23T02:42:28.991772Z"
#         }
#       ],
#       "thread_id": "Thread-30",
#       "execution_time": 0.8430302143096924,
#       "adapter_response": {},
#       "message": None,
#       "failures": 0,
#       "unique_id": "test.sample_demo.unique_order_items_order_item_key.43a40b2837"
#     }
# ```

# %% [markdown]
# ___
# #### Try the same with the other artifacts!

# %% [markdown]
# ___
# ## END OF SCRIPT
# ___
