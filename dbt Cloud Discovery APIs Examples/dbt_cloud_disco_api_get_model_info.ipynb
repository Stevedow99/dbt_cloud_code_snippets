# %% [markdown]
# ## Import Dependencies

# %%
import requests
import math
import pandas as pd

# %% [markdown]
# ## Create functions to get and process data from dbt Cloud

# %%
def get_number_of_dbt_models_in_project(dbt_cloud_token, dbt_cloud_project_env_id):
    

    # Your GraphQL endpoint
    url = 'https://metadata.cloud.getdbt.com/graphql'
    
    # The GraphQL query
    query = """
            query Models($first: Int!, $environmentId: BigInt!) {
          environment(id: $environmentId) {
            applied {
              models(first: $first) {
                totalCount
              }
            }
          }
        }
    """

    # The variables to be used in your query
    variables = {
        "environmentId": dbt_cloud_project_env_id,
        "first": 500
    }
        
    # Headers, including possibly needed authorization
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {dbt_cloud_token}',  # Only include this line if you need authorization
    }
    
    # The payload for the request
    payload = {
        'query': query,
        'variables': variables
    }
    
    # Make the POST request to the GraphQL API
    response = requests.post(url, json=payload, headers=headers)
    
    # Check for errors
    if response.status_code == 200:
        # Parse the response JSON
        data = response.json()

        # get number of models
        number_of_models_in_cloud_project = data['data']['environment']['applied']['models']['totalCount']

    else:
        print(f"Query failed to run by returning code of {response.status_code}. {response.text}")
    
    try:
        # return number of models in project
        return number_of_models_in_cloud_project
    except:
        print("there was an error getting back GraphQL Payload, please check your inputs")


def get_model_info_from_project(dbt_cloud_token, dbt_cloud_project_env_id, number_of_models_in_project):
    
    # Your GraphQL endpoint
    url = 'https://metadata.cloud.getdbt.com/graphql'
    
    # The GraphQL query
    query = """
            query Node($first: Int!, $environmentId: BigInt!, $after: String) {
              environment(id: $environmentId) {
                applied {
                  models(first: $first, after: $after) {
                    edges {
                      node {
                        tests {
                          name
                          resourceType
                        }
                        schema
                        materializedType
                        modelingLayer
                        uniqueId
                      }
                    }
                    pageInfo {
                      endCursor
                      hasNextPage
                      startCursor
                    }
                  }
                }
              }
            }
    """

    # Headers, including possibly needed authorization
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {dbt_cloud_token}',  # Only include this line if you need authorization
    }

    # calculate the number of API calls to make
    number_of_apis_to_make = math.ceil(number_of_models_in_project/500)

    # set page start
    page_start = None

    # put the parsed payload in a list
    parsed_model_data_list = []

    # loop through and make the calls
    for call in range(number_of_apis_to_make):

        # The variables to be used in your query
        variables = {
            "environmentId": dbt_cloud_project_env_id,
            "first": 500,
            "after": page_start
        }
    
        # The payload for the request
        payload = {
            'query': query,
            'variables': variables
        }
        
        # Make the POST request to the GraphQL API
        response = requests.post(url, json=payload, headers=headers)

        # get the data 
        data = response.json()['data']

        # parse the data
        parsed_data = data['environment']['applied']['models']

        # get the next page
        page_start = parsed_data['pageInfo']['endCursor']

        # add the parsed data to the list
        parsed_model_data_list.append(parsed_data['edges'])

    return parsed_model_data_list


def parse_model_data_into_a_csv(parsed_model_data_list):

    # 
    # Your data: a list of lists of dictionaries
    data_to_process = listx
    
    node_data = {}
    
    for sublist in data_to_process:
        for item in sublist:
            node = item['node']
            # Initialize or update the node entry in node_data
            if node['uniqueId'] not in node_data:
                node_data[node['uniqueId']] = {
                    'schema': node['schema'],
                    'materializedType': node['materializedType'],
                    'modelingLayer': "other" if node['modelingLayer'] is None else node['modelingLayer'],
                    'uniqueId': node['uniqueId'],
                    'tests': []  # Initialize an empty list to hold tests
                }
            # Append test names to the tests list if tests are present
            for test in node.get('tests', []):
                node_data[node['uniqueId']]['tests'].append(test['name'])
    
    # Convert the node_data dictionary to a list of dictionaries suitable for DataFrame creation
    flattened_data = list(node_data.values())

    # Convert the list of dictionaries into a DataFrame
    df = pd.DataFrame(flattened_data)

    # return the data frame
    return df

# %% [markdown]
# # Using the functions

# %% [markdown]
# ### Set inputs

# %%
# get the dbt cloud service token or personal token
dbt_cloud_token = '<< dbt cloud token goes here >>'

# the production environment id for the dbt Cloud project 
dbt_cloud_project_env_id = 123456

# %% [markdown]
# ### Get the number of dbt Models in the prod enviroment

# %%
# get the number 
number_of_models = get_number_of_dbt_models_in_project(dbt_cloud_token, dbt_cloud_project_env_id)

# log it
print(f"the number of dbt models in the env {dbt_cloud_project_env_id} is {number_of_models}")
# Out:
# the number of dbt models in the env 105436 is 40

# %% [markdown]
# ### Get all of the info for the models in the prod env

# %%
# pull back data from discovery API
prod_env_model_info = get_model_info_from_project(dbt_cloud_token, dbt_cloud_project_env_id, number_of_models)

# log that it completed
print("grabbed all of the model info from the env")
# Out:
# grabbed all of the model info from the env

# %% [markdown]
# ### Parse the list info a pandas dataframe

# %%
df_of_model_info = parse_model_data_into_a_csv(prod_env_model_info)

# %% [markdown]
# ### Save the dataframe to csv

# %%
df_of_model_info.to_csv('./dbt_models_with_info.csv', index=False)

# %% [markdown]
# ### Display the Dataframe

# %%
display(df_of_model_info)
# Out:
#                       schema materializedType modelingLayer  \
# 0             Curated_sample             view         other
# 1                    Curated             view         marts
# 2                    Curated             view         other
# 3                    Curated             view         other
# 4                    Curated             view         other
# 5                    Curated             view         other
# 6                    Curated            table         other
# 7                    Curated            table         other
# 8                    Curated            table         other
# 9                    Curated             view         marts
# 10                   Curated             view         marts
# 11    Curated_core_analytics            table         marts
# 12    Curated_core_analytics            table         marts
# 13                   Curated        ephemeral         other
# 14    Curated_core_analytics            table         marts
# 15    Curated_core_analytics            table         marts
# 16                   Curated            table         other
# 17                   Curated            table         other
# 18  Curated_aggregate_tables            table         marts
# 19                   Curated             view         other
# 20                   Curated             view         other
# 21                   Curated            table         other
# 22                   Curated             view         other
# 23                   Curated             view         other
# 24                   Curated             view  intermediate
# 25                   Curated             view  intermediate
# 26           Curated_staging             view       staging
# 27           Curated_staging             view       staging
# 28           Curated_staging             view       staging
# 29           Curated_staging             view       staging
# 30           Curated_staging             view       staging
# 31           Curated_staging             view       staging
# 32           Curated_staging             view       staging
# 33           Curated_staging             view       staging
# 34           Curated_staging             view       staging
# 35           Curated_staging             view       staging
# 36           Curated_staging             view       staging
# 37           Curated_staging             view       staging
# 38           Curated_staging             view       staging
# 39                   Curated            table         marts
#
#                                              uniqueId  \
# 0                model.primary_project.a_sample_model
# 1            model.primary_project.a_small_view_model
# 2                    model.primary_project.consume_em
# 3          model.primary_project.customer_dim_cleaned
# 4   model.primary_project.customer_nations_in_nort...
# 5           model.primary_project.customer_nations.v1
# 6           model.primary_project.customer_nations.v2
# 7           model.primary_project.customer_nations.v3
# 8            model.primary_project.customer_purchases
# 9              model.primary_project.dim_customers_ut
# 10                     model.primary_project.dim_date
# 11                    model.primary_project.dim_parts
# 12                model.primary_project.dim_suppliers
# 13              model.primary_project.ephemeral_model
# 14              model.primary_project.fct_order_items
# 15                   model.primary_project.fct_orders
# 16                 model.primary_project.large_buyers
# 17        model.primary_project.metricflow_time_spine
# 18        model.primary_project.monthly_gross_revenue
# 19               model.primary_project.my_fifth_model
# 20               model.primary_project.my_first_model
# 21      model.primary_project.my_fourth_model__python
# 22              model.primary_project.my_second_model
# 23               model.primary_project.my_third_model
# 24                  model.primary_project.order_items
# 25               model.primary_project.part_suppliers
# 26  model.primary_project.stg_airport_data__airpor...
# 27             model.primary_project.stg_customer_dim
# 28              model.primary_project.stg_product_dim
# 29            model.primary_project.stg_purchases_fct
# 30           model.primary_project.stg_sales_team_dim
# 31           model.primary_project.stg_tpch_customers
# 32          model.primary_project.stg_tpch_line_items
# 33             model.primary_project.stg_tpch_nations
# 34              model.primary_project.stg_tpch_orders
# 35               model.primary_project.stg_tpch_parts
# 36      model.primary_project.stg_tpch_part_suppliers
# 37             model.primary_project.stg_tpch_regions
# 38           model.primary_project.stg_tpch_suppliers
# 39   model.primary_project.total_passengers_by_region
#
#                                                 tests
# 0                                                  []
# 1   [not_null_a_small_view_model_one, not_null_a_s...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [not_null_customer_nations_v1_nation_key, uniq...
# 6   [not_null_customer_nations_v2_nation_key, uniq...
# 7   [not_null_customer_nations_v3_nation_key, uniq...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11  [not_null_dim_parts_part_key, unique_dim_parts...
# 12  [not_null_dim_suppliers_supplier_key, unique_d...
# 13                                                 []
# 14  [not_null_fct_order_items_nation_key, not_null...
# 15  [not_null_fct_orders_order_key, unique_fct_ord...
# 16                                                 []
# 17                                                 []
# 18  [not_null_monthly_gross_revenue_order_month, w...
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24  [not_null_order_items_order_item_key, unique_o...
# 25  [not_null_part_suppliers_part_supplier_key, un...
# 26                                                 []
# 27                                                 []
# 28                                                 []
# 29                                                 []
# 30                                                 []
# 31  [not_null_stg_tpch_customers_customer_key, uni...
# 32  [not_null_stg_tpch_line_items_order_item_key, ...
# 33  [not_null_stg_tpch_nations_nation_key, unique_...
# 34  [not_null_stg_tpch_orders_order_key, stg_tpch_...
# 35  [not_null_stg_tpch_parts_part_key, unique_stg_...
# 36  [not_null_stg_tpch_part_suppliers_part_supplie...
# 37  [not_null_stg_tpch_regions_region_key, unique_...
# 38  [not_null_stg_tpch_suppliers_supplier_key, uni...
# 39                                                 []

# %% [markdown]
# ___
#
# # END OF SCRIPT
#
# ___
