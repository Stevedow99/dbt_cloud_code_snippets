# %% [markdown]
# ## Import Dependencies

# %%
import requests
import math
import pandas as pd
import pprint

# %% [markdown]
# ## Create functions to get and process data from dbt Cloud

# %%
def get_number_of_dbt_models_in_project(dbt_cloud_token, dbt_cloud_project_env_id):
    

    # Your GraphQL endpoint
    url = 'https://metadata.cloud.getdbt.com/graphql'
    
    # The GraphQL query
    query = """
            query Models($first: Int!, $environmentId: BigInt!) {
          environment(id: $environmentId) {
            applied {
              models(first: $first) {
                totalCount
              }
            }
          }
        }
    """

    # The variables to be used in your query
    variables = {
        "environmentId": dbt_cloud_project_env_id,
        "first": 500
    }
        
    # Headers, including possibly needed authorization
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {dbt_cloud_token}',  # Only include this line if you need authorization
    }
    
    # The payload for the request
    payload = {
        'query': query,
        'variables': variables
    }
    
    # Make the POST request to the GraphQL API
    response = requests.post(url, json=payload, headers=headers)
    
    # Check for errors
    if response.status_code == 200:
        # Parse the response JSON
        data = response.json()

        # get number of models
        number_of_models_in_cloud_project = data['data']['environment']['applied']['models']['totalCount']

    else:
        print(f"Query failed to run by returning code of {response.status_code}. {response.text}")
    
    try:
        # return number of models in project
        return number_of_models_in_cloud_project
    except:
        print("there was an error getting back GraphQL Payload, please check your inputs")


def get_model_info_from_project(dbt_cloud_token, dbt_cloud_project_env_id, model_name_to_filter_for=None, number_of_models_in_project=1):
    
    # Your GraphQL endpoint
    url = 'https://metadata.cloud.getdbt.com/graphql'
    
    # The GraphQL query
    query = """
            query Node($first: Int!, $environmentId: BigInt!, $after: String, $filter: ModelAppliedFilter) {
              environment(id: $environmentId) {
                applied {
                  models(first: $first, after: $after, filter: $filter) {
                    edges {
                      node {
                        uniqueId
                        tests {
                          name
                          resourceType
                          columnName
                          description
                          testType
                          executionInfo {
                            lastRunStatus
                            lastRunGeneratedAt
                          }
                        }
                      }
                    }
                    pageInfo {
                      endCursor
                      hasNextPage
                      startCursor
                    }
                  }
                }
              }
            }
    """

    # Headers, including possibly needed authorization
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {dbt_cloud_token}',  # Only include this line if you need authorization
    }

    # calculate the number of API calls to make
    number_of_apis_to_make = math.ceil(number_of_models_in_project/500)

    # set page start
    page_start = None

    # put the parsed payload in a list
    parsed_model_data_list = []

    # set model name to filter for
    model_name_to_filter_for = "null" if model_name_to_filter_for is None else model_name_to_filter_for

    # loop through and make the calls
    for call in range(number_of_apis_to_make):

        # The variables to be used in your query
        variables = {
            "environmentId": dbt_cloud_project_env_id,
            "first": 500,
            "after": page_start,
            "filter": {
              "identifier": model_name_to_filter_for
            }
        }
    
        # The payload for the request
        payload = {
            'query': query,
            'variables': variables
        }
        
        # Make the POST request to the GraphQL API
        response = requests.post(url, json=payload, headers=headers)

        # get the data 
        data = response.json()['data']

        # parse the data
        parsed_data = data['environment']['applied']['models']

        # get the next page
        page_start = parsed_data['pageInfo']['endCursor']

        # add the parsed data to the list
        parsed_model_data_list.append(parsed_data['edges'])

    return parsed_model_data_list

# %% [markdown]
# # Using the functions

# %% [markdown]
# ### Set inputs

# %%
# get the dbt cloud service token or personal token
dbt_cloud_token = '<< dbt cloud token goes here >>'

# the production in environment id for the dbt Cloud project 
dbt_cloud_project_env_id = 123456

# %% [markdown]
# ### Get the number of dbt Models in the prod enviroment

# %%
# get the number 
number_of_models = get_number_of_dbt_models_in_project(dbt_cloud_token, dbt_cloud_project_env_id)

# log it
print(f"the number of dbt models in the env {dbt_cloud_project_env_id} is {number_of_models}")
# Out:
# the number of dbt models in the env 105436 is 40

# %% [markdown]
# ### Get test info for _ALL_ the models in the prod env

# %%
# pull back data from discovery API
prod_env_model_test_info = get_model_info_from_project(dbt_cloud_token, dbt_cloud_project_env_id, number_of_models)

# log that it completed
print("grabbed testing info for all of the models from the env")
# Out:
# grabbed all of the model info from the env

# %% [markdown]
# ### Get all of the info for a _specified_ models in the prod env

# %%
# pull back data from discovery API
prod_env_model_test_info_spec_model = get_model_info_from_project(dbt_cloud_token, dbt_cloud_project_env_id, model_name_to_filter_for='a_small_view_model')

# log that it completed
print(f"grabbed testing info for the model a_small_view_model from the env")
# Out:
# grabbed testing info for the model a_small_view_model from the env

# %% [markdown]
# ## Display outputs in JSON

# %% [markdown]
# ### Outputs example when searching for tests of just one model

# %%
pprint.pp(prod_env_model_test_info_spec_model)
# Out:
# [[{'node': {'uniqueId': 'model.primary_project.a_small_view_model',
#             'tests': [{'name': 'not_null_a_small_view_model_one',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'one',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'not_null_a_small_view_model_two',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'two',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_a_small_view_model_one',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'one',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_a_small_view_model_two',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'two',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}}]]

# %% [markdown]
# ### Outputs example when searching for tests for all models in the Prod Env

# %%
pprint.pp(prod_env_model_test_info)
# Out:
# [[{'node': {'uniqueId': 'model.primary_project.a_sample_model', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.a_small_view_model',
#             'tests': [{'name': 'not_null_a_small_view_model_one',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'one',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'not_null_a_small_view_model_two',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'two',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_a_small_view_model_one',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'one',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_a_small_view_model_two',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'two',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.consume_em', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.customer_dim_cleaned',
#             'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.customer_nations_in_north_america',
#             'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.customer_nations.v1',
#             'tests': [{'name': 'not_null_customer_nations_v1_nation_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'nation_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_customer_nations_v1_nation_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'nation_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.customer_nations.v2',
#             'tests': [{'name': 'not_null_customer_nations_v2_nation_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'nation_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_customer_nations_v2_nation_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'nation_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.customer_nations.v3',
#             'tests': [{'name': 'not_null_customer_nations_v3_nation_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'nation_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_customer_nations_v3_nation_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'nation_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.customer_purchases',
#             'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.dim_customers_ut', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.dim_date', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.dim_parts',
#             'tests': [{'name': 'not_null_dim_parts_part_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'part_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_dim_parts_part_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'part_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.dim_suppliers',
#             'tests': [{'name': 'not_null_dim_suppliers_supplier_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'supplier_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_dim_suppliers_supplier_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'supplier_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.ephemeral_model', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.fct_order_items',
#             'tests': [{'name': 'not_null_fct_order_items_nation_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'nation_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'not_null_fct_order_items_order_item_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_item_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_fct_order_items_order_item_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_item_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.fct_orders',
#             'tests': [{'name': 'not_null_fct_orders_order_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_fct_orders_order_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.large_buyers', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.metricflow_time_spine',
#             'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.monthly_gross_revenue',
#             'tests': [{'name': 'not_null_monthly_gross_revenue_order_month',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_month',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'warn_gross_revenue_is_low_monthly_gross_revenue_gross_revenue',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'gross_revenue',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'warn',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.my_fifth_model', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.my_first_model', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.my_fourth_model__python',
#             'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.my_second_model', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.my_third_model', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.order_items',
#             'tests': [{'name': 'not_null_order_items_order_item_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_item_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_order_items_order_item_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_item_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.part_suppliers',
#             'tests': [{'name': 'not_null_part_suppliers_part_supplier_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'part_supplier_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_part_suppliers_part_supplier_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'part_supplier_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.stg_airport_data__airport_capacity',
#             'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.stg_customer_dim', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.stg_product_dim', 'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.stg_purchases_fct',
#             'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.stg_sales_team_dim',
#             'tests': []}},
#   {'node': {'uniqueId': 'model.primary_project.stg_tpch_customers',
#             'tests': [{'name': 'not_null_stg_tpch_customers_customer_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'customer_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_stg_tpch_customers_customer_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'customer_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.stg_tpch_line_items',
#             'tests': [{'name': 'not_null_stg_tpch_line_items_order_item_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_item_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_stg_tpch_line_items_order_item_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_item_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.stg_tpch_nations',
#             'tests': [{'name': 'not_null_stg_tpch_nations_nation_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'nation_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_stg_tpch_nations_nation_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'nation_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.stg_tpch_orders',
#             'tests': [{'name': 'not_null_stg_tpch_orders_order_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'stg_tpch_orders_assert_positive_price',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': None,
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_stg_tpch_orders_order_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'order_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.stg_tpch_parts',
#             'tests': [{'name': 'not_null_stg_tpch_parts_part_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'part_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_stg_tpch_parts_part_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'part_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.stg_tpch_part_suppliers',
#             'tests': [{'name': 'not_null_stg_tpch_part_suppliers_part_supplier_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'part_supplier_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_stg_tpch_part_suppliers_part_supplier_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'part_supplier_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.stg_tpch_regions',
#             'tests': [{'name': 'not_null_stg_tpch_regions_region_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'region_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_stg_tpch_regions_region_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'region_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.stg_tpch_suppliers',
#             'tests': [{'name': 'not_null_stg_tpch_suppliers_supplier_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'supplier_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}},
#                       {'name': 'unique_stg_tpch_suppliers_supplier_key',
#                        'resourceType': 'TestAppliedStateNestedNode',
#                        'columnName': 'supplier_key',
#                        'description': None,
#                        'testType': 'GENERIC_DATA_TEST',
#                        'executionInfo': {'lastRunStatus': 'pass',
#                                          'lastRunGeneratedAt': '2024-03-09T14:47:08.974Z'}}]}},
#   {'node': {'uniqueId': 'model.primary_project.total_passengers_by_region',
#             'tests': []}}]]

# %% [markdown]
# ___
#
# # END OF SCRIPT
#
# ___
